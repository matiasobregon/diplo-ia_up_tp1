# %%
import pandas as pd
import os

# %%
# DataSources
# Cargo la fuente de datos con la que voy a trabajar en el proyecto
# "The largest public dataset of 90 000+ games published on Steam" | Dataset de juegos publicados en la tienda de Steam
# Fuente: https://www.kaggle.com/datasets/artermiloff/steam-games-dataset/data
df = pd.read_csv("data/games_march2025_cleaned.csv")

# %%
tam_archivo = os.path.getsize('data/games_march2025_cleaned.csv') / (1024**2)
print (f"Tamaño del archivo: {tam_archivo} MB")
# Out:
# Tamaño del archivo: 446.93098735809326 MB

# %%
df.shape # El DataFrame tiene que tener al menos 50K registros y 10 columnaspara este TP
# Out:
# (89618, 47)

# %%
# veo la estructura del DataFrame
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 89618 entries, 0 to 89617
# Data columns (total 47 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   appid                     89618 non-null  int64
#  1   name                      89618 non-null  str
#  2   release_date              89618 non-null  str
#  3   required_age              89618 non-null  int64
#  4   price                     89618 non-null  float64
#  5   dlc_count                 89618 non-null  int64
#  6   detailed_description      89421 non-null  str
#  7   about_the_game            89398 non-null  str
#  8   short_description         89498 non-null  str
#  9   reviews                   10401 non-null  str
#  10  header_image              89618 non-null  str
#  11  website                   41114 non-null  str
#  12  support_url               44110 non-null  str
#  13  support_email             78798 non-null  str
#  14  windows                   89618 non-null  bool
#  15  mac                       89618 non-null  bool
#  16  linux                     89618 non-null  bool
#  17  metacritic_score          89618 non-null  int64
#  18  metacritic_url            3547 non-null   str
#  19  achievements              89618 non-null  int64
#  20  recommendations           89618 non-null  int64
#  21  notes                     16643 non-null  str
#  22  supported_languages       89618 non-null  str
#  23  full_audio_languages      89618 non-null  str
#  24  packages                  89618 non-null  str
#  25  developers                89618 non-null  str
#  26  publishers                89618 non-null  str
#  27  categories                89618 non-null  str
#  28  genres                    89618 non-null  str
#  29  screenshots               89618 non-null  str
#  30  movies                    89618 non-null  str
#  31  user_score                89618 non-null  int64
#  32  score_rank                39 non-null     float64
#  33  positive                  89618 non-null  int64
#  34  negative                  89618 non-null  int64
#  35  estimated_owners          89618 non-null  str
#  36  average_playtime_forever  89618 non-null  int64
#  37  average_playtime_2weeks   89618 non-null  int64
#  38  median_playtime_forever   89618 non-null  int64
#  39  median_playtime_2weeks    89618 non-null  int64
#  40  discount                  89618 non-null  int64
#  41  peak_ccu                  89618 non-null  int64
#  42  tags                      89618 non-null  str
#  43  pct_pos_total             89618 non-null  int64
#  44  num_reviews_total         89618 non-null  int64
#  45  pct_pos_recent            89618 non-null  int64
#  46  num_reviews_recent        89618 non-null  int64
# dtypes: bool(3), float64(2), int64(19), str(23)
# memory usage: 30.3 MB

# %%
# Obtengo una muestra al azar del DataFrame
sample= df.sample()

# %%
sample.describe()
# Out:
#            appid  required_age  price  dlc_count  metacritic_score  \
# count        1.0           1.0   1.00        1.0               1.0
# mean   2392230.0           0.0   4.99        0.0               0.0
# std          NaN           NaN    NaN        NaN               NaN
# min    2392230.0           0.0   4.99        0.0               0.0
# 25%    2392230.0           0.0   4.99        0.0               0.0
# 50%    2392230.0           0.0   4.99        0.0               0.0
# 75%    2392230.0           0.0   4.99        0.0               0.0
# max    2392230.0           0.0   4.99        0.0               0.0
#
#        achievements  recommendations  user_score  score_rank  positive  ...  \
# count           1.0              1.0         1.0         0.0       1.0  ...
# mean           10.0            173.0         0.0         NaN       0.0  ...
# std             NaN              NaN         NaN         NaN       NaN  ...
# min            10.0            173.0         0.0         NaN       0.0  ...
# 25%            10.0            173.0         0.0         NaN       0.0  ...
# 50%            10.0            173.0         0.0         NaN       0.0  ...
# 75%            10.0            173.0         0.0         NaN       0.0  ...
# max            10.0            173.0         0.0         NaN       0.0  ...
#
#        average_playtime_forever  average_playtime_2weeks  \
# count                       1.0                      1.0
# mean                        0.0                      0.0
# std                         NaN                      NaN
# min                         0.0                      0.0
# 25%                         0.0                      0.0
# 50%                         0.0                      0.0
# 75%                         0.0                      0.0
# max                         0.0                      0.0
#
#        median_playtime_forever  median_playtime_2weeks  discount  peak_ccu  \
# count                      1.0                     1.0       1.0       1.0
# mean                       0.0                     0.0       0.0       1.0
# std                        NaN                     NaN       NaN       NaN
# min                        0.0                     0.0       0.0       1.0
# 25%                        0.0                     0.0       0.0       1.0
# 50%                        0.0                     0.0       0.0       1.0
# 75%                        0.0                     0.0       0.0       1.0
# max                        0.0                     0.0       0.0       1.0
#
#        pct_pos_total  num_reviews_total  pct_pos_recent  num_reviews_recent
# count            1.0                1.0             1.0                 1.0
# mean           100.0              173.0            -1.0                -1.0
# std              NaN                NaN             NaN                 NaN
# min            100.0              173.0            -1.0                -1.0
# 25%            100.0              173.0            -1.0                -1.0
# 50%            100.0              173.0            -1.0                -1.0
# 75%            100.0              173.0            -1.0                -1.0
# max            100.0              173.0            -1.0                -1.0
#
# [8 rows x 21 columns]

# %%
cols=sample.columns
for i in cols:
    print (f"{i}: {sample[i].iloc[0]}")
# Out:
# appid: 2392230
# name: The Groom of Gallagher Mansion
# release_date: 2023-09-30
# required_age: 0
# price: 4.99
# dlc_count: 0
# detailed_description: 'Even death won't do us part,' Elias Gallagher — the ghost of a man you've just met — mutters. He's resigned to unhappiness, but perhaps you hold the key to breaking his curse... if you're so inclined. In a bid to stop the Occult History and Sciences Investigation Club (that's the OHSIC, and don't you forget it!) from losing funding, President Taylor Potts and you, the Vice President, have got to find a way to attract new members somehow. And what better way to prove that the club still has value to the campus board than to prove that ghosts really do exist? Dressed in some exquisite wedding attire and armed with a rose and earpiece, you're marched right up to the old Gallagher Mansion, a site of some grisly murders circa early 1900s, to trick a dead man into thinking that you too were abandoned at the altar. Will you find glory and fame, riches and spoils? Or perhaps this whole thing is a lot more than you bargained for and you'll actually fall in love with a ghost... Content Warnings: Blood Death Disability &amp; Implied Ableism Sexual Content Violence Features: Over 27k words long Self-insert protagonist with customizable pronouns 2 Love Interests 4 Endings Full Voice Acting
# about_the_game: 'Even death won't do us part,' Elias Gallagher — the ghost of a man you've just met — mutters. He's resigned to unhappiness, but perhaps you hold the key to breaking his curse... if you're so inclined. In a bid to stop the Occult History and Sciences Investigation Club (that's the OHSIC, and don't you forget it!) from losing funding, President Taylor Potts and you, the Vice President, have got to find a way to attract new members somehow. And what better way to prove that the club still has value to the campus board than to prove that ghosts really do exist? Dressed in some exquisite wedding attire and armed with a rose and earpiece, you're marched right up to the old Gallagher Mansion, a site of some grisly murders circa early 1900s, to trick a dead man into thinking that you too were abandoned at the altar. Will you find glory and fame, riches and spoils? Or perhaps this whole thing is a lot more than you bargained for and you'll actually fall in love with a ghost... Content Warnings: Blood Death Disability &amp; Implied Ableism Sexual Content Violence Features: Over 27k words long Self-insert protagonist with customizable pronouns 2 Love Interests 4 Endings Full Voice Acting
# short_description: Hunt down a beheaded ghost to save your college club from losing funding! It'll be a piece of cake— wait, what do you mean he wants to marry you!? The Groom of Gallagher Mansion is spooky comedic romantic visual novel full of laughs and scares all around!
# reviews: nan
# header_image: https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2392230/header.jpg?t=1741049182
# website: nan
# support_url: nan
# support_email: snaccpopstudios@gmail.com
# windows: True
# mac: True
# linux: True
# metacritic_score: 0
# metacritic_url: nan
# achievements: 10
# recommendations: 173
# notes: The Groom of Gallagher Mansion is a dark story featuring heavy themes of death and trauma, as well as light sexual content between consenting adults. This game is not suitable for minors.
# supported_languages: ['English']
# full_audio_languages: ['English']
# packages: [{'title': 'Buy The Groom of Gallagher Mansion', 'description': '', 'subs': [{'text': 'The Groom of Gallagher Mansion - $4.99', 'description': '', 'price': 4.99}]}]
# developers: ['SnaccPop Studios']
# publishers: ['SnaccPop Studios']
# categories: ['Single-player', 'Steam Achievements', 'Captions available', 'Family Sharing']
# genres: ['Casual', 'Indie', 'Simulation']
# screenshots: ['https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2392230/ss_0521de47bccfdc34cc53bdd53d8ae6652ee407fe.1920x1080.jpg?t=1741049182', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2392230/ss_b82b0763d036e8231997fddee954f75b2f0a0a46.1920x1080.jpg?t=1741049182', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2392230/ss_626ce1e8f1654fa6ca5eba72beacaa2f52cbb3c3.1920x1080.jpg?t=1741049182', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2392230/ss_42efee61fd9ab536df86266224f2325292faec35.1920x1080.jpg?t=1741049182', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2392230/ss_0cb703493597bedfe6d6e920be8731b12d9b175e.1920x1080.jpg?t=1741049182']
# movies: []
# user_score: 0
# score_rank: nan
# positive: 0
# negative: 0
# estimated_owners: 0 - 20000
# average_playtime_forever: 0
# average_playtime_2weeks: 0
# median_playtime_forever: 0
# median_playtime_2weeks: 0
# discount: 0
# peak_ccu: 1
# tags: []
# pct_pos_total: 100
# num_reviews_total: 173
# pct_pos_recent: -1
# num_reviews_recent: -1

# %% [markdown]
# en base a esa muestra, elimino las columnas que no aportan valor al análisis
#
# - detailed_description
# - about_the_game
# - short_description
# - header_image
# - website
# - support_url
# - support_email
# - packages
# - screenshots
# - movies

# %%
columns = ['detailed_description', 'about_the_game', 'short_description', 'header_image', 'website', 'support_url', 'support_email', 'packages', 'screenshots', 'movies']
df = df.drop(columns=columns)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 89618 entries, 0 to 89617
# Data columns (total 37 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   appid                     89618 non-null  int64
#  1   name                      89618 non-null  str
#  2   release_date              89618 non-null  str
#  3   required_age              89618 non-null  int64
#  4   price                     89618 non-null  float64
#  5   dlc_count                 89618 non-null  int64
#  6   reviews                   10401 non-null  str
#  7   windows                   89618 non-null  bool
#  8   mac                       89618 non-null  bool
#  9   linux                     89618 non-null  bool
#  10  metacritic_score          89618 non-null  int64
#  11  metacritic_url            3547 non-null   str
#  12  achievements              89618 non-null  int64
#  13  recommendations           89618 non-null  int64
#  14  notes                     16643 non-null  str
#  15  supported_languages       89618 non-null  str
#  16  full_audio_languages      89618 non-null  str
#  17  developers                89618 non-null  str
#  18  publishers                89618 non-null  str
#  19  categories                89618 non-null  str
#  20  genres                    89618 non-null  str
#  21  user_score                89618 non-null  int64
#  22  score_rank                39 non-null     float64
#  23  positive                  89618 non-null  int64
#  24  negative                  89618 non-null  int64
#  25  estimated_owners          89618 non-null  str
#  26  average_playtime_forever  89618 non-null  int64
#  27  average_playtime_2weeks   89618 non-null  int64
#  28  median_playtime_forever   89618 non-null  int64
#  29  median_playtime_2weeks    89618 non-null  int64
#  30  discount                  89618 non-null  int64
#  31  peak_ccu                  89618 non-null  int64
#  32  tags                      89618 non-null  str
#  33  pct_pos_total             89618 non-null  int64
#  34  num_reviews_total         89618 non-null  int64
#  35  pct_pos_recent            89618 non-null  int64
#  36  num_reviews_recent        89618 non-null  int64
# dtypes: bool(3), float64(2), int64(19), str(13)
# memory usage: 23.5 MB

# %%
df.to_csv("data/games_march2025_reduced.csv", index=False)

# %%
tam_original = tam_archivo
tam_archivo = os.path.getsize('games_march2025_reduced.csv') / (1024**2)
print (f"Tamaño original: {tam_original} MB")
print (f"Tamaño nuevo   : {tam_archivo} MB")
# Out:
# Tamaño original: 446.93098735809326 MB
# Tamaño nuevo   : 55.32654285430908 MB
